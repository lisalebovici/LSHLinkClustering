# %%
kershaw = pd.read_csv('../data/Kershaw.csv').iloc[:, 1:5]

# %%
kershaw.shape
# Out:
# (1000, 4)

# %%
kershaw_data = np.array(kershaw.iloc[:, 0:3])
kershaw_labels = np.array(kershaw.iloc[:, 3])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(kershaw_data[:, 0], kershaw_data[:, 1], kershaw_data[:, 2], alpha = 0.1)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z');

# %%
kershaw.columns
# Out:
# Index(['start_speed', 'pfx_x', 'pfx_z', 'pitch_type'], dtype='object')

# %%
a
# Out:
# array([0])

# %%
b
# Out:
# array([1, 2])

# %%
a = np.array([0])
b = np.array([1,2])
np.r_[a, b]
# Out:
# array([0, 1, 2])

# %%
g1 = np.where(kersh_clusters == np.unique(kersh_clusters)[0])[0]
g2 = np.where(kersh_clusters == np.unique(kersh_clusters)[1])[0]
g3 = np.where(kersh_clusters == np.unique(kersh_clusters)[2])[0]

# %%
kershaw = pd.read_csv('../data/Kershaw.csv').iloc[:, 1:5]

kershaw_data = np.array(kershaw.iloc[:, 0:3])
kershaw_labels = np.array(kershaw.iloc[:, 3])
np.unique(kershaw_labels)

a = np.array([0])
b = np.min(kershaw_data, axis = 0)[1:3]
shift = np.r_[a, b]

kershaw_data_shifted = kershaw_data - shift

# %%
kersh_clusters = lsh.LSHLink(kershaw_data_shifted, A = 1.1, l = 10, k = 100, seed1 = 12, seed2 = 6, cutoff = 3)

# %%
print(np.unique(kersh_clusters))
print(len(np.unique(kersh_clusters)))
# Out:
# [  58  222 1185]
# 3

# %%
TRUTH = np.c_[kershaw_data, kclust]
g1 = np.where(kclust == np.unique(kclust)[0])[0]
g2 = np.where(kclust == np.unique(kclust)[1])[0]
# g3 = np.where(kclust == np.unique(kclust)[2])[0]
# g4 = np.where(kersh_clusters == np.unique(kersh_clusters)[3])[0]
# g5 = np.where(kersh_clusters == np.unique(kersh_clusters)[4])[0]
# g6 = np.where(kersh_clusters == np.unique(kersh_clusters)[5])[0]
# g7 = np.where(kersh_clusters == np.unique(kersh_clusters)[6])[0]
# g8 = np.where(kersh_clusters == np.unique(kersh_clusters)[7])[0]
# g9 = np.where(kersh_clusters == np.unique(kersh_clusters)[8])[0]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(TRUTH[g1, 0], TRUTH[g1, 1], TRUTH[g1, 2], alpha = 0.1)
ax.scatter(TRUTH[g2, 0], TRUTH[g2, 1], TRUTH[g2, 2], alpha = 0.1)
# ax.scatter(TRUTH[g3, 0], TRUTH[g3, 1], TRUTH[g3, 2], alpha = 0.1)
# ax.scatter(TRUTH[g4, 0], TRUTH[g4, 1], TRUTH[g4, 2], alpha = 0.1)
# ax.scatter(TRUTH[g5, 0], TRUTH[g5, 1], TRUTH[g5, 2], alpha = 0.1)
# ax.scatter(TRUTH[g6, 0], TRUTH[g6, 1], TRUTH[g6, 2], alpha = 0.1)
# ax.scatter(TRUTH[g7, 0], TRUTH[g7, 1], TRUTH[g7, 2], alpha = 0.1)
# ax.scatter(TRUTH[g8, 0], TRUTH[g8, 1], TRUTH[g8, 2], alpha = 0.1)
# ax.scatter(TRUTH[g9, 0], TRUTH[g9, 1], TRUTH[g9, 2], alpha = 0.1)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z')
plt.show()

# %%
z = linkage(kershaw_data_shifted, method = 'single')

# %%
matplotlib.rcParams['lines.linewidth'] = 0.1
dendrogram(z, color_threshold = 4)
plt.gcf().set_size_inches(20, 10)
plt.show();

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib

# %%
matplotlib.rcParams['lines.linewidth'] = 0.1
dendrogram(Z, color_threshold = 4)
plt.gcf().set_size_inches(20, 10)
plt.show();

# %%
################################# START PAYING ATTENTION HERE #################################

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import lshlink as lsh

# %%
def kmeans(k, data):
    n = data.shape[0]
    clusters = np.zeros(n)
    updates = True
    iterations = 0
    
    # randomly initialize k cluster centers from input data
    idx = list(np.random.choice(range(n), k))
    centers = data[idx,]
    
    while updates:
        updates = False
        iterations += 1
        print('iteration: ' + str(iterations))
        counter = 0

        # assign each point to closest cluster center
        for i in range(n):
            point = data[i,]
            closest_cluster = np.argmin(np.linalg.norm(point - centers, axis = 1))

            if clusters[i] != closest_cluster:
                clusters[i] = closest_cluster
                updates = True
                counter += 1

        print('number of updates: %s' % str(counter))

        # change each cluster center to be in the middle of its points
        for j in range(k):
            cluster_idx = np.where(clusters == j)[0]
            centers[j] = np.mean(data[cluster_idx, :], axis = 0)
            
    return(clusters, centers)

# %%
################################# CURVEBALL / FASTBALL #################################

# %%
kershaw = pd.read_csv('../data/Kershaw.csv').iloc[:, 1:5]
kershaw_data = np.array(kershaw.iloc[:, 0:3])
kershaw_labels = np.array(kershaw.iloc[:, 3])
kershaw.shape
# Out:
# (1000, 4)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(kershaw_data[:, 0], kershaw_data[:, 1], kershaw_data[:, 2], alpha = 0.5)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z');

# %%
np.random.seed(1)
clust, cen = kmeans(2, kershaw_data)
# Out:
# iteration: 1
# number of updates: 448
# iteration: 2
# number of updates: 215
# iteration: 3
# number of updates: 19
# iteration: 4
# number of updates: 1
# iteration: 5
# number of updates: 0

# %%
TRUTH = np.c_[kershaw_data, clust]
g1 = np.where(clust == np.unique(clust)[0])[0]
g2 = np.where(clust == np.unique(clust)[1])[0]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(TRUTH[g1, 0], TRUTH[g1, 1], TRUTH[g1, 2], alpha = 0.5)
ax.scatter(TRUTH[g2, 0], TRUTH[g2, 1], TRUTH[g2, 2], alpha = 0.5)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z')
plt.show()

# %%
check = np.zeros((1000,))
check[np.where(kershaw_labels == 'FF')[0]] = 0
check[np.where(kershaw_labels == 'CU')[0]] = 1

# %%
print(sum(check == clust) / 1000)
print(sum((check == clust)[np.where(kershaw_labels == 'FF')[0]]) / len(np.where(kershaw_labels == 'FF')[0]))
print(sum((check == clust)[np.where(kershaw_labels == 'CU')[0]]) / len(np.where(kershaw_labels == 'CU')[0]))
# Out:
# 1.0
# 1.0
# 1.0

# %%
################################# CURVEBALL / FASTBALL / SLIDER #################################

# %%
kershawFCS = pd.read_csv('../data/KershawFCS.csv').iloc[:, 1:5]
kershawFCS.shape
# Out:
# (450, 4)

# %%
kershawFCS_data = np.array(kershawFCS.iloc[:, 0:3])
kershawFCS_labels = np.array(kershawFCS.iloc[:, 3])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(kershawFCS_data[:, 0], kershawFCS_data[:, 1], kershawFCS_data[:, 2], alpha = 0.5)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z');

# %%
np.random.seed(1)
FCSclust, FCScen = kmeans(3, kershawFCS_data)
# Out:
# iteration: 1
# number of updates: 295
# iteration: 2
# number of updates: 7
# iteration: 3
# number of updates: 2
# iteration: 4
# number of updates: 1
# iteration: 5
# number of updates: 0

# %%
TRUTH = np.c_[kershawFCS_data, FCSclust]
g1 = np.where(FCSclust == np.unique(FCSclust)[0])[0]
g2 = np.where(FCSclust == np.unique(FCSclust)[1])[0]
g3 = np.where(FCSclust == np.unique(FCSclust)[2])[0]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(TRUTH[g1, 0], TRUTH[g1, 1], TRUTH[g1, 2], alpha = 0.5)
ax.scatter(TRUTH[g2, 0], TRUTH[g2, 1], TRUTH[g2, 2], alpha = 0.5)
ax.scatter(TRUTH[g3, 0], TRUTH[g3, 1], TRUTH[g3, 2], alpha = 0.5)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z')
plt.show()

# %%
FCScheck = np.zeros((450,))
FCScheck[np.where(kershawFCS_labels == 'CU')[0]] = 0
FCScheck[np.where(kershawFCS_labels == 'FF')[0]] = 1
FCScheck[np.where(kershawFCS_labels == 'SL')[0]] = 2

# %%
print(sum(FCScheck == FCSclust) / 450)
print(sum((FCScheck == FCSclust)[np.where(kershawFCS_labels == 'CU')[0]]) / len(np.where(kershawFCS_labels == 'CU')[0]))
print(sum((FCScheck == FCSclust)[np.where(kershawFCS_labels == 'FF')[0]]) / len(np.where(kershawFCS_labels == 'FF')[0]))
print(sum((FCScheck == FCSclust)[np.where(kershawFCS_labels == 'SL')[0]]) / len(np.where(kershawFCS_labels == 'SL')[0]))
# Out:
# 0.96
# 1.0
# 0.9933333333333333
# 0.8866666666666667

# %%
################################# CURVEBALL / FASTBALL / CHANGEUP #################################

# %%
kershawFCC = pd.read_csv('../data/KershawFCC.csv').iloc[:, 1:5]
kershawFCC.shape
# Out:
# (450, 4)

# %%
kershawFCC_data = np.array(kershawFCC.iloc[:, 0:3])
kershawFCC_labels = np.array(kershawFCC.iloc[:, 3])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(kershawFCC_data[:, 0], kershawFCC_data[:, 1], kershawFCC_data[:, 2], alpha = 0.5)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z');

# %%
np.random.seed(1)
FCCclust, FCCcen = kmeans(3, kershawFCC_data)
# Out:
# iteration: 1
# number of updates: 302
# iteration: 2
# number of updates: 3
# iteration: 3
# number of updates: 0

# %%
TRUTH = np.c_[kershawFCC_data, FCCclust]
g1 = np.where(FCCclust == np.unique(FCCclust)[0])[0]
g2 = np.where(FCCclust == np.unique(FCCclust)[1])[0]
g3 = np.where(FCCclust == np.unique(FCCclust)[2])[0]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(TRUTH[g1, 0], TRUTH[g1, 1], TRUTH[g1, 2], alpha = 0.5)
ax.scatter(TRUTH[g2, 0], TRUTH[g2, 1], TRUTH[g2, 2], alpha = 0.5)
ax.scatter(TRUTH[g3, 0], TRUTH[g3, 1], TRUTH[g3, 2], alpha = 0.5)
ax.view_init(azim=160)
ax.set_xlabel('start_speed')
ax.set_ylabel('pfx_x')
ax.set_zlabel('pfx_z')
plt.show()

# %%
FCCcheck = np.zeros((450,))
FCCcheck[np.where(kershawFCC_labels == 'CH')[0]] = 0
FCCcheck[np.where(kershawFCC_labels == 'CU')[0]] = 1
FCCcheck[np.where(kershawFCC_labels == 'FF')[0]] = 2

# %%
print(sum(FCCcheck == FCCclust) / 450)
print(sum((FCCcheck == FCCclust)[np.where(kershawFCC_labels == 'CH')[0]]) / len(np.where(kershawFCC_labels == 'CH')[0]))
print(sum((FCCcheck == FCCclust)[np.where(kershawFCC_labels == 'CU')[0]]) / len(np.where(kershawFCC_labels == 'CU')[0]))
print(sum((FCCcheck == FCCclust)[np.where(kershawFCC_labels == 'FF')[0]]) / len(np.where(kershawFCC_labels == 'FF')[0]))
# Out:
# 0.9888888888888889
# 0.9666666666666667
# 1.0
# 1.0
